# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
yp = np.load('predict.npy')
yr = np.load('real.npy')
nodes = 80
batch = 31
a = plt.plot(list(range(0,12)),yp[batch,:,nodes],yr[batch,:,nodes])
